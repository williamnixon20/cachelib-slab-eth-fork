# %%
import pandas as pd
df = pd.read_csv('efficiency_result_processed.csv')

# %%
disabled_miss_ratios = df[df['rebalance_strategy'] == 'disabled'].set_index(['trace_name', 'wsr', 'allocator'])['miss_ratio']
def get_disabled_miss_ratio(row):
    key = (row['trace_name'], row['wsr'], row['allocator'])
    return disabled_miss_ratios.get(key, None)

df['disabled_miss_ratio'] = df.apply(get_disabled_miss_ratio, axis=1)
df['miss_ratio_reduction_from_disabled_ratio'] = df['miss_ratio_reduction_from_disabled'] / df['disabled_miss_ratio']

# %%
df.columns
# Out:
# Index(['rebalanced_slabs', 'n_rebalanced_slabs', 'miss_ratio', 'throughput',
#        'n_alloc_failures', 'trace_name', 'number_of_requests', 'wsr',
#        'slab_size', 'slab_cnt', 'rebalance_strategy', 'allocator', 'tag',
#        'monitor_interval', 'uuid', 'qps', 'wss', 'number_of_objects',
#        'file_name', 'memory_requirement', 'compulsory_miss_ratio_byte',
#        'max_req_size', 'max_obj_size', 'trace_file', 'time_span', 'purpose',
#        'min_req_size', 'number_of_req_GiB', 'cpu_requirement', 'download_path',
#        'category', 'compulsory_miss_ratio_req', 'number_of_obj_GiB',
#        'num_slab_classes', 'frequency_mean', 'min_obj_size',
#        'poolRebalanceIntervalSec', 'lru2qColdPct', 'thresholdMI',
#        'mhMovingAverageParam', 'mhMinDiff', 'rebalanceOnRecordAccess',
#        'countColdTailHitsOnly', 'rebalanceStrategy', 'rebalanceDiffRatio',
#        'lruRefreshSec', 'allocFactor', 'mhOnlyUpdateHitIfRebalance',
# ...

# %%
display(df[(df['trace_name'] == 'meta_202210_kv') & (df['allocator'] == 'LRU')].sort_values(by = 'miss_ratio_reduction_from_disabled_ratio', ascending=False)\
    [['wsr', 'allocator', 'rebalance_strategy', 'miss_ratio_reduction_from_disabled_ratio', 'miss_ratio_reduction_from_disabled']].head(3))

display(df[(df['trace_name'] == 'meta_202210_kv') & (df['allocator'] == 'LRU2Q')].sort_values(by = 'miss_ratio_reduction_from_disabled_ratio', ascending=False)\
    [['wsr', 'allocator', 'rebalance_strategy', 'miss_ratio_reduction_from_disabled_ratio', 'miss_ratio_reduction_from_disabled']].head(3))

display(df[(df['trace_name'] == 'meta_202210_kv') & (df['allocator'] == 'TINYLFU')].sort_values(by = 'miss_ratio_reduction_from_disabled_ratio', ascending=False)\
    [['wsr', 'allocator', 'rebalance_strategy', 'miss_ratio_reduction_from_disabled_ratio', 'miss_ratio_reduction_from_disabled']].head(3))
# Out:
#      wsr allocator   rebalance_strategy  \
# 54  0.02       LRU  marginal-hits-tuned
# 78  0.05       LRU  marginal-hits-tuned
# 76  0.05       LRU                 hits
#
#     miss_ratio_reduction_from_disabled_ratio  \
# 54                                  0.474875
# 78                                  0.455651
# 76                                  0.449388
#
#     miss_ratio_reduction_from_disabled
# 54                            0.038649
# 78                            0.028619
# 76                            0.028226
#       wsr allocator   rebalance_strategy  \
# 62  0.020     LRU2Q  marginal-hits-tuned
# 38  0.010     LRU2Q  marginal-hits-tuned
# 14  0.005     LRU2Q  marginal-hits-tuned
#
#     miss_ratio_reduction_from_disabled_ratio  \
# 62                                  0.481815
# 38                                  0.449273
# 14                                  0.430332
#
#     miss_ratio_reduction_from_disabled
# 62                            0.037087
# ...

# %%
display(df[(df['category'] == 'twitter-kv') & (df['allocator'] == 'LRU')].sort_values(by = 'miss_ratio_reduction_from_disabled_ratio', ascending=False)\
    [['wsr', 'allocator', 'rebalance_strategy', 'miss_ratio_reduction_from_disabled_ratio', 'miss_ratio_reduction_from_disabled']].head(3))

display(df[(df['category'] == 'twitter-kv') & (df['allocator'] == 'LRU2Q')].sort_values(by = 'miss_ratio_reduction_from_disabled_ratio', ascending=False)\
    [['wsr', 'allocator', 'rebalance_strategy', 'miss_ratio_reduction_from_disabled_ratio', 'miss_ratio_reduction_from_disabled']].head(3))

display(df[(df['category'] == 'twitter-kv') & (df['allocator'] == 'TINYLFU')].sort_values(by = 'miss_ratio_reduction_from_disabled_ratio', ascending=False)\
    [['wsr', 'allocator', 'rebalance_strategy', 'miss_ratio_reduction_from_disabled_ratio', 'miss_ratio_reduction_from_disabled']].head(3))
# Out:
#       wsr allocator rebalance_strategy  \
# 2061  0.1       LRU           tail-age
# 2062  0.1       LRU               hits
# 2059  0.1       LRU      eviction-rate
#
#       miss_ratio_reduction_from_disabled_ratio  \
# 2061                                  0.985254
# 2062                                  0.985113
# 2059                                  0.982887
#
#       miss_ratio_reduction_from_disabled
# 2061                            0.201308
# 2062                            0.201279
# 2059                            0.200825
#       wsr allocator   rebalance_strategy  \
# 2072  0.1     LRU2Q  marginal-hits-tuned
# 2070  0.1     LRU2Q                 hits
# 2067  0.1     LRU2Q        eviction-rate
#
#       miss_ratio_reduction_from_disabled_ratio  \
# 2072                                  0.986302
# 2070                                  0.984207
# 2067                                  0.981722
#
#       miss_ratio_reduction_from_disabled
# ...

# %%
display(df[(df['category'] == 'wiki-cdn') & (df['allocator'] == 'LRU')].sort_values(by = 'miss_ratio_reduction_from_disabled_ratio', ascending=False)\
    [['wsr', 'allocator', 'rebalance_strategy', 'miss_ratio_reduction_from_disabled_ratio', 'miss_ratio_reduction_from_disabled']].head(3))

display(df[(df['category'] == 'wiki-cdn') & (df['allocator'] == 'LRU2Q')].sort_values(by = 'miss_ratio_reduction_from_disabled_ratio', ascending=False)\
    [['wsr', 'allocator', 'rebalance_strategy', 'miss_ratio_reduction_from_disabled_ratio', 'miss_ratio_reduction_from_disabled']].head(3))

display(df[(df['category'] == 'wiki-cdn') & (df['allocator'] == 'TINYLFU')].sort_values(by = 'miss_ratio_reduction_from_disabled_ratio', ascending=False)\
    [['wsr', 'allocator', 'rebalance_strategy', 'miss_ratio_reduction_from_disabled_ratio', 'miss_ratio_reduction_from_disabled']].head(3))
# Out:
#        wsr allocator   rebalance_strategy  \
# 2492  0.01       LRU  marginal-hits-tuned
# 2486  0.01       LRU                 lama
# 2540  0.01       LRU  marginal-hits-tuned
#
#       miss_ratio_reduction_from_disabled_ratio  \
# 2492                                  0.553278
# 2486                                  0.520074
# 2540                                  0.479365
#
#       miss_ratio_reduction_from_disabled
# 2492                            0.144489
# 2486                            0.135818
# 2540                            0.170037
#        wsr allocator   rebalance_strategy  \
# 2500  0.01     LRU2Q  marginal-hits-tuned
# 2494  0.01     LRU2Q                 lama
# 2548  0.01     LRU2Q  marginal-hits-tuned
#
#       miss_ratio_reduction_from_disabled_ratio  \
# 2500                                  0.537881
# 2494                                  0.509784
# 2548                                  0.465237
#
#       miss_ratio_reduction_from_disabled
# ...

# %%
display(df[(df['category'] == 'meta-cdn') & (df['allocator'] == 'LRU')].sort_values(by = 'miss_ratio_reduction_from_disabled_ratio', ascending=False)\
    [['wsr', 'allocator', 'rebalance_strategy', 'miss_ratio_reduction_from_disabled_ratio', 'miss_ratio_reduction_from_disabled']].head(3))

display(df[(df['category'] == 'meta-cdn') & (df['allocator'] == 'LRU2Q')].sort_values(by = 'miss_ratio_reduction_from_disabled_ratio', ascending=False)\
    [['wsr', 'allocator', 'rebalance_strategy', 'miss_ratio_reduction_from_disabled_ratio', 'miss_ratio_reduction_from_disabled']].head(3))

display(df[(df['category'] == 'meta-cdn') & (df['allocator'] == 'TINYLFU')].sort_values(by = 'miss_ratio_reduction_from_disabled_ratio', ascending=False)\
    [['wsr', 'allocator', 'rebalance_strategy', 'miss_ratio_reduction_from_disabled_ratio', 'miss_ratio_reduction_from_disabled']].head(3))
# Out:
#       wsr allocator rebalance_strategy  \
# 480  0.01       LRU               lama
# 528  0.01       LRU               lama
# 504  0.01       LRU               lama
#
#      miss_ratio_reduction_from_disabled_ratio  \
# 480                                  0.076355
# 528                                  0.074636
# 504                                  0.073225
#
#      miss_ratio_reduction_from_disabled
# 480                            0.031705
# 528                            0.043185
# 504                            0.050746
#       wsr allocator rebalance_strategy  \
# 536  0.01     LRU2Q               lama
# 512  0.01     LRU2Q               lama
# 488  0.01     LRU2Q               lama
#
#      miss_ratio_reduction_from_disabled_ratio  \
# 536                                  0.073899
# 512                                  0.072351
# 488                                  0.070881
#
#      miss_ratio_reduction_from_disabled
# 536                            0.041531
# ...

# %%
display(df[(df['trace_name'] == 'meta_202210_kv') & (df['allocator'] == 'LRU')].sort_values(by = 'miss_ratio_reduction_from_disabled_ratio', ascending=True)\
    [['wsr', 'allocator', 'rebalance_strategy', 'miss_ratio_reduction_from_disabled_ratio', 'miss_ratio_reduction_from_disabled']].head(3))

display(df[(df['trace_name'] == 'meta_202210_kv') & (df['allocator'] == 'LRU2Q')].sort_values(by = 'miss_ratio_reduction_from_disabled_ratio', ascending=True)\
    [['wsr', 'allocator', 'rebalance_strategy', 'miss_ratio_reduction_from_disabled_ratio', 'miss_ratio_reduction_from_disabled']].head(3))

display(df[(df['trace_name'] == 'meta_202210_kv') & (df['allocator'] == 'TINYLFU')].sort_values(by = 'miss_ratio_reduction_from_disabled_ratio', ascending=True)\
    [['wsr', 'allocator', 'rebalance_strategy', 'miss_ratio_reduction_from_disabled_ratio', 'miss_ratio_reduction_from_disabled']].head(3))
# Out:
#      wsr allocator rebalance_strategy  \
# 151  0.4       LRU      marginal-hits
# 123  0.2       LRU           tail-age
# 99   0.1       LRU           tail-age
#
#      miss_ratio_reduction_from_disabled_ratio  \
# 151                                 -0.166260
# 123                                 -0.025622
# 99                                  -0.008331
#
#      miss_ratio_reduction_from_disabled
# 151                           -0.005877
# 123                           -0.001108
# 99                            -0.000442
#        wsr allocator rebalance_strategy  \
# 159  0.400     LRU2Q      marginal-hits
# 135  0.200     LRU2Q      marginal-hits
# 10   0.005     LRU2Q           free-mem
#
#      miss_ratio_reduction_from_disabled_ratio  \
# 159                                 -0.183534
# 135                                 -0.044743
# 10                                   0.000000
#
#      miss_ratio_reduction_from_disabled
# 159                           -0.006385
# ...

# %%
display(df[(df['category'] == 'twitter-kv') & (df['allocator'] == 'LRU')].sort_values(by = 'miss_ratio_reduction_from_disabled_ratio', ascending=True)\
    [['wsr', 'allocator', 'rebalance_strategy', 'miss_ratio_reduction_from_disabled_ratio', 'miss_ratio_reduction_from_disabled']].head(3))

display(df[(df['category'] == 'twitter-kv') & (df['allocator'] == 'LRU2Q')].sort_values(by = 'miss_ratio_reduction_from_disabled_ratio', ascending=True)\
    [['wsr', 'allocator', 'rebalance_strategy', 'miss_ratio_reduction_from_disabled_ratio', 'miss_ratio_reduction_from_disabled']].head(3))

display(df[(df['category'] == 'twitter-kv') & (df['allocator'] == 'TINYLFU')].sort_values(by = 'miss_ratio_reduction_from_disabled_ratio', ascending=True)\
    [['wsr', 'allocator', 'rebalance_strategy', 'miss_ratio_reduction_from_disabled_ratio', 'miss_ratio_reduction_from_disabled']].head(3))
# Out:
#       wsr allocator rebalance_strategy  \
# 1900  0.1       LRU      eviction-rate
# 1272  0.1       LRU      eviction-rate
# 2507  0.1       LRU      eviction-rate
#
#       miss_ratio_reduction_from_disabled_ratio  \
# 1900                                 -3.183376
# 1272                                 -1.294936
# 2507                                 -1.120223
#
#       miss_ratio_reduction_from_disabled
# 1900                           -0.201410
# 1272                           -0.061504
# 2507                           -0.006485
#       wsr allocator rebalance_strategy  \
# 1908  0.1     LRU2Q      eviction-rate
# 1280  0.1     LRU2Q      eviction-rate
# 2515  0.1     LRU2Q      eviction-rate
#
#       miss_ratio_reduction_from_disabled_ratio  \
# 1908                                 -3.339393
# 1280                                 -1.310286
# 2515                                 -1.172123
#
#       miss_ratio_reduction_from_disabled
# 1908                           -0.206538
# ...

# %%
display(df[(df['category'] == 'wiki-cdn') & (df['allocator'] == 'LRU')].sort_values(by = 'miss_ratio_reduction_from_disabled_ratio', ascending=False)\
    [['wsr', 'allocator', 'rebalance_strategy', 'miss_ratio_reduction_from_disabled_ratio', 'miss_ratio_reduction_from_disabled']].head(3))

display(df[(df['category'] == 'wiki-cdn') & (df['allocator'] == 'LRU2Q')].sort_values(by = 'miss_ratio_reduction_from_disabled_ratio', ascending=False)\
    [['wsr', 'allocator', 'rebalance_strategy', 'miss_ratio_reduction_from_disabled_ratio', 'miss_ratio_reduction_from_disabled']].head(3))

display(df[(df['category'] == 'wiki-cdn') & (df['allocator'] == 'TINYLFU')].sort_values(by = 'miss_ratio_reduction_from_disabled_ratio', ascending=False)\
    [['wsr', 'allocator', 'rebalance_strategy', 'miss_ratio_reduction_from_disabled_ratio', 'miss_ratio_reduction_from_disabled']].head(3))
# Out:
#        wsr allocator   rebalance_strategy  \
# 2536  0.01       LRU  marginal-hits-tuned
# 2530  0.01       LRU                 lama
# 2584  0.01       LRU  marginal-hits-tuned
#
#       miss_ratio_reduction_from_disabled_ratio  \
# 2536                                  0.553278
# 2530                                  0.520074
# 2584                                  0.479365
#
#       miss_ratio_reduction_from_disabled
# 2536                            0.144489
# 2530                            0.135818
# 2584                            0.170037
#        wsr allocator   rebalance_strategy  \
# 2544  0.01     LRU2Q  marginal-hits-tuned
# 2538  0.01     LRU2Q                 lama
# 2592  0.01     LRU2Q  marginal-hits-tuned
#
#       miss_ratio_reduction_from_disabled_ratio  \
# 2544                                  0.537881
# 2538                                  0.509784
# 2592                                  0.465237
#
#       miss_ratio_reduction_from_disabled
# ...

# %%
"""
slab rebalance can significantly improve cache efficiency
"""

max_reduction_by_category = df.groupby('category')['miss_ratio_reduction_from_disabled'].max().sort_values(ascending=False)
max_reduction_details = df.loc[df.groupby('category')['miss_ratio_reduction_from_disabled'].idxmax()]

print("Details of configurations achieving maximum reduction by category:")
display_cols = ['category', 'trace_name', 'wsr', 'allocator', 'rebalance_strategy', 
                'miss_ratio_reduction_from_disabled', 'miss_ratio', 'rebalanced_slabs']
max_reduction_details[display_cols].sort_values('miss_ratio_reduction_from_disabled', ascending=False)
# Out:
# Details of configurations achieving maximum reduction by category:
#         category             trace_name   wsr allocator   rebalance_strategy  \
# 2200  twitter-kv      twitter_cluster50  0.01   TINYLFU        marginal-hits
# 2540    wiki-cdn             wiki_2019u  0.01       LRU  marginal-hits-tuned
# 340      meta-kv  meta_memcache_2024_kv  0.01       LRU                 hits
# 504     meta-cdn              meta_rnha  0.01       LRU                 lama
#
#       miss_ratio_reduction_from_disabled  miss_ratio  rebalanced_slabs
# 2200                            0.329998    0.280395              2792
# 2540                            0.170037    0.184676              9457
# 340                             0.069548    0.127822                84
# 504                             0.050746    0.642264              3022

# %%
# Filter for category == 'twitter-kv' and wsr == 0.1
print("Step 1: Initial filtering")
filtered_df = df[(df['category'] == 'twitter-kv') & (df['wsr'] == 0.1)]
print(f"Data after filtering for category='twitter-kv' and wsr=0.1: {len(filtered_df)} rows")

# Find all existing allocator-rebalance strategy combinations
print("\nStep 2: Finding existing combinations")
existing_combinations = set(filtered_df[['allocator', 'rebalance_strategy']].drop_duplicates().apply(tuple, axis=1))
print(f"Total existing allocator-rebalance strategy combinations: {len(existing_combinations)}")
print("Existing combinations:")
for combo in sorted(existing_combinations):
    print(f"  {combo[0]} + {combo[1]}")

# For each trace, check which combinations it has
print("\nStep 3: Checking completeness of each trace")
trace_combinations = {}
incomplete_traces = []

for trace_name in filtered_df['trace_name'].unique():
    trace_data = filtered_df[filtered_df['trace_name'] == trace_name]
    trace_combos = set(trace_data[['allocator', 'rebalance_strategy']].drop_duplicates().apply(tuple, axis=1))
    trace_combinations[trace_name] = trace_combos
    
    missing_combos = existing_combinations - trace_combos
    if missing_combos:
        incomplete_traces.append(trace_name)
        print(f"  {trace_name}: Missing {len(missing_combos)} combinations")
        for missing in sorted(missing_combos):
            print(f"    - {missing[0]} + {missing[1]}")
    else:
        print(f"  {trace_name}: Complete (has all {len(existing_combinations)} combinations)")

# Keep only traces that have all combinations
complete_traces = [trace for trace in trace_combinations.keys() 
                  if trace_combinations[trace] == existing_combinations]

print(f"\nStep 4: Filtering to complete traces only")
print(f"Complete traces: {len(complete_traces)} out of {len(trace_combinations)} total traces")
print("Complete traces:", complete_traces)

# Filter to only complete traces
final_df = filtered_df[filtered_df['trace_name'].isin(complete_traces)]
print(f"Final dataset: {len(final_df)} rows")

# Group by allocator and rebalance strategy, compute statistics
print("\nStep 5: Computing statistics")
if len(final_df) > 0:
    stats = final_df.groupby(['allocator', 'rebalance_strategy'])['miss_ratio_reduction_from_lru_disabled'].agg([
        'count',  # number of rows
        'min',    # minimum
        'median',
        'mean',   # mean
        'max',    # maximum
        lambda x: x.quantile(0.9)  # 90th percentile
    ]).round(6)
    
    # Rename the lambda column
    stats.columns = ['count', 'min', 'median', 'mean', 'max', 'p90']
    
    print("Statistics for miss_ratio_reduction_from_lru_disabled:")
    print("=" * 80)
    display(stats)
else:
    print("No complete traces found - cannot compute statistics")
# Out:
# Step 1: Initial filtering
# Data after filtering for category='twitter-kv' and wsr=0.1: 1139 rows
#
# Step 2: Finding existing combinations
# Total existing allocator-rebalance strategy combinations: 24
# Existing combinations:
#   LRU + disabled
#   LRU + eviction-rate
#   LRU + free-mem
#   LRU + hits
#   LRU + lama
#   LRU + marginal-hits
#   LRU + marginal-hits-tuned
#   LRU + tail-age
#   LRU2Q + disabled
#   LRU2Q + eviction-rate
#   LRU2Q + free-mem
#   LRU2Q + hits
#   LRU2Q + lama
#   LRU2Q + marginal-hits
#   LRU2Q + marginal-hits-tuned
#   LRU2Q + tail-age
#   TINYLFU + disabled
#   TINYLFU + eviction-rate
#   TINYLFU + free-mem
#   TINYLFU + hits
#   TINYLFU + lama
#   TINYLFU + marginal-hits
#   TINYLFU + marginal-hits-tuned
#   TINYLFU + tail-age
#
# Step 3: Checking completeness of each trace
#   twitter_cluster10: Complete (has all 24 combinations)
#   twitter_cluster11: Complete (has all 24 combinations)
#   twitter_cluster12: Missing 22 combinations
# ...

# %%
# Filter for category == 'twitter-kv' and wsr == 0.1
print("Step 1: Initial filtering")
filtered_df = df[(df['category'] == 'twitter-kv') & (df['wsr'] == 0.1)]
print(f"Data after filtering for category='twitter-kv' and wsr=0.1: {len(filtered_df)} rows")

# Find all existing allocator-rebalance strategy combinations
print("\nStep 2: Finding existing combinations")
existing_combinations = set(filtered_df[['allocator', 'rebalance_strategy']].drop_duplicates().apply(tuple, axis=1))
print(f"Total existing allocator-rebalance strategy combinations: {len(existing_combinations)}")
print("Existing combinations:")
for combo in sorted(existing_combinations):
    print(f"  {combo[0]} + {combo[1]}")

# For each trace, check which combinations it has
print("\nStep 3: Checking completeness of each trace")
trace_combinations = {}
incomplete_traces = []

for trace_name in filtered_df['trace_name'].unique():
    trace_data = filtered_df[filtered_df['trace_name'] == trace_name]
    trace_combos = set(trace_data[['allocator', 'rebalance_strategy']].drop_duplicates().apply(tuple, axis=1))
    trace_combinations[trace_name] = trace_combos
    
    missing_combos = existing_combinations - trace_combos
    if missing_combos:
        incomplete_traces.append(trace_name)
        print(f"  {trace_name}: Missing {len(missing_combos)} combinations")
        for missing in sorted(missing_combos):
            print(f"    - {missing[0]} + {missing[1]}")
    else:
        print(f"  {trace_name}: Complete (has all {len(existing_combinations)} combinations)")

# Keep only traces that have all combinations
complete_traces = [trace for trace in trace_combinations.keys() 
                  if trace_combinations[trace] == existing_combinations]

print(f"\nStep 4: Filtering to complete traces only")
print(f"Complete traces: {len(complete_traces)} out of {len(trace_combinations)} total traces")
print("Complete traces:", complete_traces)

# Filter to only complete traces
final_df = filtered_df[filtered_df['trace_name'].isin(complete_traces)]
print(f"Final dataset: {len(final_df)} rows")

# Group by allocator and rebalance strategy, compute statistics
print("\nStep 5: Computing statistics")
if len(final_df) > 0:
    stats = final_df.groupby(['allocator', 'rebalance_strategy'])['miss_ratio_percent_reduction_from_lru_disabled'].agg([
        'count',  # number of rows
        'min',    # minimum
        'median',
        'mean',   # mean
        'max',    # maximum
        lambda x: x.quantile(0.9)  # 90th percentile
    ]).round(6)
    
    # Rename the lambda column
    stats.columns = ['count', 'min', 'median', 'mean', 'max', 'p90']
    
    print("Statistics for miss_ratio_reduction_from_lru_disabled:")
    print("=" * 80)
    display(stats)
else:
    print("No complete traces found - cannot compute statistics")
# Out:
# Step 1: Initial filtering
# Data after filtering for category='twitter-kv' and wsr=0.1: 1139 rows
#
# Step 2: Finding existing combinations
# Total existing allocator-rebalance strategy combinations: 24
# Existing combinations:
#   LRU + disabled
#   LRU + eviction-rate
#   LRU + free-mem
#   LRU + hits
#   LRU + lama
#   LRU + marginal-hits
#   LRU + marginal-hits-tuned
#   LRU + tail-age
#   LRU2Q + disabled
#   LRU2Q + eviction-rate
#   LRU2Q + free-mem
#   LRU2Q + hits
#   LRU2Q + lama
#   LRU2Q + marginal-hits
#   LRU2Q + marginal-hits-tuned
#   LRU2Q + tail-age
#   TINYLFU + disabled
#   TINYLFU + eviction-rate
#   TINYLFU + free-mem
#   TINYLFU + hits
#   TINYLFU + lama
#   TINYLFU + marginal-hits
#   TINYLFU + marginal-hits-tuned
#   TINYLFU + tail-age
#
# Step 3: Checking completeness of each trace
#   twitter_cluster10: Complete (has all 24 combinations)
#   twitter_cluster11: Complete (has all 24 combinations)
#   twitter_cluster12: Missing 22 combinations
# ...

# %%
# Filter for category == 'twitter-kv' and wsr == 0.1
print("Step 1: Initial filtering")
filtered_df = df[(df['category'] == 'twitter-kv') & (df['wsr'] == 0.01)]
print(f"Data after filtering for category='twitter-kv' and wsr=0.1: {len(filtered_df)} rows")

# Find all existing allocator-rebalance strategy combinations
print("\nStep 2: Finding existing combinations")
existing_combinations = set(filtered_df[['allocator', 'rebalance_strategy']].drop_duplicates().apply(tuple, axis=1))
print(f"Total existing allocator-rebalance strategy combinations: {len(existing_combinations)}")
print("Existing combinations:")
for combo in sorted(existing_combinations):
    print(f"  {combo[0]} + {combo[1]}")

# For each trace, check which combinations it has
print("\nStep 3: Checking completeness of each trace")
trace_combinations = {}
incomplete_traces = []

for trace_name in filtered_df['trace_name'].unique():
    trace_data = filtered_df[filtered_df['trace_name'] == trace_name]
    trace_combos = set(trace_data[['allocator', 'rebalance_strategy']].drop_duplicates().apply(tuple, axis=1))
    trace_combinations[trace_name] = trace_combos
    
    missing_combos = existing_combinations - trace_combos
    if missing_combos:
        incomplete_traces.append(trace_name)
        print(f"  {trace_name}: Missing {len(missing_combos)} combinations")
        for missing in sorted(missing_combos):
            print(f"    - {missing[0]} + {missing[1]}")
    else:
        print(f"  {trace_name}: Complete (has all {len(existing_combinations)} combinations)")

# Keep only traces that have all combinations
complete_traces = [trace for trace in trace_combinations.keys() 
                  if trace_combinations[trace] == existing_combinations]

print(f"\nStep 4: Filtering to complete traces only")
print(f"Complete traces: {len(complete_traces)} out of {len(trace_combinations)} total traces")
print("Complete traces:", complete_traces)

# Filter to only complete traces
final_df = filtered_df[filtered_df['trace_name'].isin(complete_traces)]
print(f"Final dataset: {len(final_df)} rows")

# Group by allocator and rebalance strategy, compute statistics
print("\nStep 5: Computing statistics")
if len(final_df) > 0:
    stats = final_df.groupby(['allocator', 'rebalance_strategy'])['miss_ratio_reduction_from_lru_disabled'].agg([
        'count',  # number of rows
        'min',    # minimum
        'median',
        'mean',   # mean
        'max',    # maximum
        lambda x: x.quantile(0.9)  # 90th percentile
    ]).round(6)
    
    # Rename the lambda column
    stats.columns = ['count', 'min', 'median', 'mean', 'max', 'p90']
    
    print("Statistics for miss_ratio_reduction_from_lru_disabled:")
    print("=" * 80)
    display(stats)
else:
    print("No complete traces found - cannot compute statistics")
# Out:
# Step 1: Initial filtering
# Data after filtering for category='twitter-kv' and wsr=0.1: 839 rows
#
# Step 2: Finding existing combinations
# Total existing allocator-rebalance strategy combinations: 24
# Existing combinations:
#   LRU + disabled
#   LRU + eviction-rate
#   LRU + free-mem
#   LRU + hits
#   LRU + lama
#   LRU + marginal-hits
#   LRU + marginal-hits-tuned
#   LRU + tail-age
#   LRU2Q + disabled
#   LRU2Q + eviction-rate
#   LRU2Q + free-mem
#   LRU2Q + hits
#   LRU2Q + lama
#   LRU2Q + marginal-hits
#   LRU2Q + marginal-hits-tuned
#   LRU2Q + tail-age
#   TINYLFU + disabled
#   TINYLFU + eviction-rate
#   TINYLFU + free-mem
#   TINYLFU + hits
#   TINYLFU + lama
#   TINYLFU + marginal-hits
#   TINYLFU + marginal-hits-tuned
#   TINYLFU + tail-age
#
# Step 3: Checking completeness of each trace
#   twitter_cluster10: Complete (has all 24 combinations)
#   twitter_cluster11: Complete (has all 24 combinations)
#   twitter_cluster12: Missing 1 combinations
# ...

# %%
# Filter for meta_memcache_2024_kv trace
print("Analyzing meta_memcache_2024_kv trace")
meta_df = df[df['trace_name'] == 'meta_memcache_2024_kv']
print(f"Total rows for meta_memcache_2024_kv: {len(meta_df)}")

# Filter for tail-age and marginal-hits-tuned strategies
strategies_to_compare = ['tail-age', 'marginal-hits-tuned']
comparison_df = meta_df[meta_df['rebalance_strategy'].isin(strategies_to_compare)]

print(f"\nData available for comparison strategies: {len(comparison_df)} rows")
print(f"Available strategies: {sorted(comparison_df['rebalance_strategy'].unique())}")
print(f"Available allocators: {sorted(comparison_df['allocator'].unique())}")
print(f"Available WSR values: {sorted(comparison_df['wsr'].unique())}")

# Pivot to get miss ratios side by side for comparison
pivot_data = comparison_df.pivot_table(
    index=['allocator', 'wsr'], 
    columns='rebalance_strategy', 
    values='miss_ratio', 
    aggfunc='first'  # Since there's only one record per group
)

print("\nMiss ratios by allocator and WSR:")
print("=" * 50)
display(pivot_data.round(6))

# Calculate relative increase from marginal-hits-tuned to tail-age
if 'tail-age' in pivot_data.columns and 'marginal-hits-tuned' in pivot_data.columns:
    comparison_results = pivot_data.copy()
    comparison_results['absolute_increase'] = comparison_results['tail-age'] - comparison_results['marginal-hits-tuned']
    comparison_results['relative_increase_pct'] = ((comparison_results['tail-age'] - comparison_results['marginal-hits-tuned']) / comparison_results['marginal-hits-tuned']) * 100
    
    print("\nComparison: Tail-Age vs Marginal-Hits-Tuned")
    print("=" * 60)
    display(comparison_results.round(6))
    
    print("\nSummary of miss ratio increases (Tail-Age relative to Marginal-Hits-Tuned):")
    print("=" * 75)
    for (allocator, wsr), row in comparison_results.iterrows():
        if pd.notna(row['absolute_increase']) and pd.notna(row['relative_increase_pct']):
            tail_age_mr = row['tail-age']
            marginal_hits_tuned_mr = row['marginal-hits-tuned']
            abs_increase = row['absolute_increase']
            rel_increase = row['relative_increase_pct']
            print(f"{allocator} (WSR={wsr}):")
            print(f"  Marginal-Hits-Tuned: {marginal_hits_tuned_mr:.6f}")
            print(f"  Tail-Age: {tail_age_mr:.6f}")
            print(f"  Increase: +{abs_increase:.6f} (+{rel_increase:.2f}%)")
            print()
        else:
            print(f"{allocator} (WSR={wsr}): Missing data for comparison")
else:
    print("\nCannot perform comparison - missing strategy data")
    print(f"Available strategies: {list(pivot_data.columns)}")
# Out:
# Analyzing meta_memcache_2024_kv trace
# Total rows for meta_memcache_2024_kv: 144
#
# Data available for comparison strategies: 36 rows
# Available strategies: ['marginal-hits-tuned', 'tail-age']
# Available allocators: ['LRU', 'LRU2Q', 'TINYLFU']
# Available WSR values: [np.float64(0.01), np.float64(0.02), np.float64(0.05), np.float64(0.1), np.float64(0.2), np.float64(0.4)]
#
# Miss ratios by allocator and WSR:
# ...
# rebalance_strategy  marginal-hits-tuned  tail-age
# allocator wsr
# LRU       0.01                 0.135193  0.197737
#           0.02                 0.104690  0.179228
#           0.05                 0.092537  0.136340
#           0.10                 0.088630  0.117553
#           0.20                 0.087482  0.104026
#           0.40                 0.087056  0.090822
# LRU2Q     0.01                 0.129174  0.208417
#           0.02                 0.104412  0.195937
#           0.05                 0.092200  0.134358
# ...

# %%
# Out:
# Step 4: Calculating miss ratio deltas
# Clean data (no NaN): 105 rows out of 105 total
#
# Analysis 1: Tail-Age vs Marginal-Hits-Tuned
# ...
# Average miss ratio delta (tail-age - marginal-hits-tuned): 0.014201
# Average relative delta (tail-age vs marginal-hits-tuned): 6.51%
# Standard deviation: 0.046463
# Min delta: -0.035120
# Max delta: 0.289968
#
# Analysis 2: Tail-Age vs Disabled
# ...
# Cases where tail-age has HIGHER miss ratio than disabled: 45/105
# Percentage of time tail-age performs WORSE than disabled: 42.9%
# Average delta (tail-age - disabled): -0.011590
#
# Detailed breakdown by allocator:
# ...
# LRU:
#   Avg delta vs marginal-hits-tuned: 0.013570 (5.08%)
#   Worse than disabled: 14/35 (40.0%)
# LRU2Q:
#   Avg delta vs marginal-hits-tuned: 0.016835 (9.18%)
#   Worse than disabled: 14/35 (40.0%)
# TINYLFU:
#   Avg delta vs marginal-hits-tuned: 0.012199 (5.26%)
#   Worse than disabled: 17/35 (48.6%)

# %%
# Filter for category == 'twitter-kv', wsr == 0.01, and the three strategies
print("Step 1: Filtering data")
filtered_df = df[
    (df['category'] == 'twitter-kv') & 
    (df['wsr'] == 0.01) & 
    (df['rebalance_strategy'].isin(['tail-age', 'marginal-hits-tuned', 'disabled']))
]
print(f"Filtered data: {len(filtered_df)} rows")
print(f"Available strategies: {sorted(filtered_df['rebalance_strategy'].unique())}")
print(f"Available allocators: {sorted(filtered_df['allocator'].unique())}")
print(f"Unique traces: {len(filtered_df['trace_name'].unique())}")

# Check completeness - each (trace_name, allocator) group should have 3 strategies
print("\nStep 2: Checking data completeness")
completeness_check = filtered_df.groupby(['trace_name', 'allocator'])['rebalance_strategy'].count()
incomplete_groups = completeness_check[completeness_check != 3]

if len(incomplete_groups) > 0:
    print(f"Warning: {len(incomplete_groups)} groups don't have all 3 strategies:")
    for (trace, allocator), count in incomplete_groups.items():
        strategies = filtered_df[(filtered_df['trace_name'] == trace) & 
                                (filtered_df['allocator'] == allocator)]['rebalance_strategy'].tolist()
        print(f"  {trace} + {allocator}: only has {strategies} ({count} strategies)")
else:
    print("All groups have complete data (3 strategies each)")

# Pivot to get miss ratios side by side for comparison
print("\nStep 3: Reshaping data for comparison")
pivot_data = filtered_df.pivot_table(
    index=['trace_name', 'allocator'], 
    columns='rebalance_strategy', 
    values='miss_ratio', 
    aggfunc='first'
)

print(f"Pivot table shape: {pivot_data.shape}")
print("Sample of pivot data:")
display(pivot_data.head().round(6))

# Calculate deltas
print("\nStep 4: Calculating miss ratio deltas")
if all(strategy in pivot_data.columns for strategy in ['tail-age', 'marginal-hits-tuned', 'disabled']):
    # Calculate deltas
    pivot_data['delta_tail_age_vs_marginal_hits_tuned'] = pivot_data['tail-age'] - pivot_data['marginal-hits-tuned']
    pivot_data['relative_delta_tail_age_vs_marginal_hits_tuned'] = ((pivot_data['tail-age'] - pivot_data['marginal-hits-tuned']) / pivot_data['marginal-hits-tuned']) * 100
    pivot_data['delta_tail_age_vs_disabled'] = pivot_data['tail-age'] - pivot_data['disabled']
    
    # Remove rows with any NaN values for clean analysis
    clean_data = pivot_data.dropna()
    print(f"Clean data (no NaN): {len(clean_data)} rows out of {len(pivot_data)} total")
    
    if len(clean_data) > 0:
        # Analysis 1: Average delta (tail-age - marginal-hits-tuned)
        avg_delta_vs_tuned = clean_data['delta_tail_age_vs_marginal_hits_tuned'].mean()
        avg_relative_delta_vs_tuned = clean_data['relative_delta_tail_age_vs_marginal_hits_tuned'].mean()
        print(f"\nAnalysis 1: Tail-Age vs Marginal-Hits-Tuned")
        print("=" * 50)
        print(f"Average miss ratio delta (tail-age - marginal-hits-tuned): {avg_delta_vs_tuned:.6f}")
        print(f"Average relative delta (tail-age vs marginal-hits-tuned): {avg_relative_delta_vs_tuned:.2f}%")
        print(f"Standard deviation: {clean_data['delta_tail_age_vs_marginal_hits_tuned'].std():.6f}")
        print(f"Min delta: {clean_data['delta_tail_age_vs_marginal_hits_tuned'].min():.6f}")
        print(f"Max delta: {clean_data['delta_tail_age_vs_marginal_hits_tuned'].max():.6f}")
        
        # Analysis 2: Percent of time tail-age vs disabled is positive
        positive_vs_disabled = (clean_data['delta_tail_age_vs_disabled'] > 0).sum()
        total_comparisons = len(clean_data)
        percent_positive_vs_disabled = (positive_vs_disabled / total_comparisons) * 100
        
        print(f"\nAnalysis 2: Tail-Age vs Disabled")
        print("=" * 40)
        print(f"Cases where tail-age has HIGHER miss ratio than disabled: {positive_vs_disabled}/{total_comparisons}")
        print(f"Percentage of time tail-age performs WORSE than disabled: {percent_positive_vs_disabled:.1f}%")
        print(f"Average delta (tail-age - disabled): {clean_data['delta_tail_age_vs_disabled'].mean():.6f}")
        
        # Detailed breakdown by allocator
        print(f"\nDetailed breakdown by allocator:")
        print("=" * 60)
        for allocator in clean_data.index.get_level_values('allocator').unique():
            allocator_data = clean_data[clean_data.index.get_level_values('allocator') == allocator]
            
            avg_vs_tuned = allocator_data['delta_tail_age_vs_marginal_hits_tuned'].mean()
            avg_relative_vs_tuned = allocator_data['relative_delta_tail_age_vs_marginal_hits_tuned'].mean()
            positive_vs_disabled_alloc = (allocator_data['delta_tail_age_vs_disabled'] > 0).sum()
            total_alloc = len(allocator_data)
            percent_pos_alloc = (positive_vs_disabled_alloc / total_alloc) * 100 if total_alloc > 0 else 0
            
            print(f"{allocator}:")
            print(f"  Avg delta vs marginal-hits-tuned: {avg_vs_tuned:.6f} ({avg_relative_vs_tuned:.2f}%)")
            print(f"  Worse than disabled: {positive_vs_disabled_alloc}/{total_alloc} ({percent_pos_alloc:.1f}%)")
            
    else:
        print("No complete data available for analysis")
        
else:
    missing_strategies = [s for s in ['tail-age', 'marginal-hits-tuned', 'disabled'] if s not in pivot_data.columns]
    print(f"Cannot perform analysis - missing strategies: {missing_strategies}")
# Out:
# Step 1: Filtering data
# Filtered data: 315 rows
# Available strategies: ['disabled', 'marginal-hits-tuned', 'tail-age']
# Available allocators: ['LRU', 'LRU2Q', 'TINYLFU']
# Unique traces: 35
#
# Step 2: Checking data completeness
# All groups have complete data (3 strategies each)
#
# Step 3: Reshaping data for comparison
# Pivot table shape: (105, 3)
# Sample of pivot data:
# rebalance_strategy           disabled  marginal-hits-tuned  tail-age
# trace_name        allocator
# twitter_cluster10 LRU        0.499899             0.499899  0.499899
#                   LRU2Q      0.499899             0.499899  0.499899
#                   TINYLFU    0.499900             0.499899  0.499899
# twitter_cluster11 LRU        0.453759             0.428254  0.466493
#                   LRU2Q      0.422608             0.399495  0.448502
# Step 4: Calculating miss ratio deltas
# Clean data (no NaN): 105 rows out of 105 total
#
# Analysis 1: Tail-Age vs Marginal-Hits-Tuned
# ...

# %%
# Step 1: Filter for category == 'twitter-kv'
print("Step 1: Initial filtering for twitter-kv")
twitter_df = df[df['category'] == 'twitter-kv']
print(f"Data after filtering for category='twitter-kv': {len(twitter_df)} rows")

# Step 2: Find all existing allocator-rebalance strategy combinations
print("\nStep 2: Finding existing combinations")
existing_combinations = set(twitter_df[['allocator', 'rebalance_strategy']].drop_duplicates().apply(tuple, axis=1))
print(f"Total existing allocator-rebalance strategy combinations: {len(existing_combinations)}")
print("Existing combinations:")
for combo in sorted(existing_combinations):
    print(f"  {combo[0]} + {combo[1]}")

# Step 3: For each trace, check which combinations it has
print("\nStep 3: Checking completeness of each trace")
trace_combinations = {}
incomplete_traces = []

for trace_name in twitter_df['trace_name'].unique():
    trace_data = twitter_df[twitter_df['trace_name'] == trace_name]
    trace_combos = set(trace_data[['allocator', 'rebalance_strategy']].drop_duplicates().apply(tuple, axis=1))
    trace_combinations[trace_name] = trace_combos
    
    missing_combos = existing_combinations - trace_combos
    if missing_combos:
        incomplete_traces.append(trace_name)
        print(f"  {trace_name}: Missing {len(missing_combos)} combinations")
        for missing in sorted(missing_combos):
            print(f"    - {missing[0]} + {missing[1]}")
    else:
        print(f"  {trace_name}: Complete (has all {len(existing_combinations)} combinations)")

# Step 4: Keep only traces that have all combinations
complete_traces = [trace for trace in trace_combinations.keys() 
                  if trace_combinations[trace] == existing_combinations]

print(f"\nStep 4: Filtering to complete traces only")
print(f"Complete traces: {len(complete_traces)} out of {len(trace_combinations)} total traces")
print("Complete traces:", complete_traces)

# Filter to only complete traces
complete_twitter_df = twitter_df[twitter_df['trace_name'].isin(complete_traces)]
print(f"Complete twitter-kv dataset: {len(complete_twitter_df)} rows")

# Step 5: Filter for eviction-rate strategy
print("\nStep 5: Filtering for eviction-rate strategy")
eviction_rate_df = complete_twitter_df[complete_twitter_df['rebalance_strategy'] == 'eviction-rate']
print(f"Data for eviction-rate strategy: {len(eviction_rate_df)} rows")

if len(eviction_rate_df) > 0:
    print(f"Available WSR values: {sorted(eviction_rate_df['wsr'].unique())}")
    print(f"Available allocators: {sorted(eviction_rate_df['allocator'].unique())}")
    
    # Step 6: Group by wsr and allocator, compute statistics
    print("\nStep 6: Computing statistics by WSR and allocator")
    
    metrics = [
        'miss_ratio_reduction_from_disabled',
        'miss_ratio_percent_reduction_from_disabled', 
        'miss_ratio_reduction_from_lru_disabled',
        'miss_ratio_percent_reduction_from_lru_disabled'
    ]
    
    for metric in metrics:
        if metric in eviction_rate_df.columns:
            print(f"\n{metric}:")
            print("=" * 60)
            stats = eviction_rate_df.groupby(['wsr', 'allocator'])[metric].agg([
                'count',
                'min',
                'mean', 
                'max'
            ]).round(6)
            display(stats)
        else:
            print(f"\nWarning: Column '{metric}' not found in data")
            
else:
    print("No data found for eviction-rate strategy in complete traces")
    print("Available strategies in complete traces:")
    available_strategies = complete_twitter_df['rebalance_strategy'].unique()
    for strategy in sorted(available_strategies):
        print(f"  - {strategy}")
# Out:
# Step 1: Initial filtering for twitter-kv
# Data after filtering for category='twitter-kv': 1978 rows
#
# Step 2: Finding existing combinations
# Total existing allocator-rebalance strategy combinations: 24
# Existing combinations:
#   LRU + disabled
#   LRU + eviction-rate
#   LRU + free-mem
#   LRU + hits
#   LRU + lama
#   LRU + marginal-hits
#   LRU + marginal-hits-tuned
#   LRU + tail-age
#   LRU2Q + disabled
#   LRU2Q + eviction-rate
#   LRU2Q + free-mem
#   LRU2Q + hits
#   LRU2Q + lama
#   LRU2Q + marginal-hits
#   LRU2Q + marginal-hits-tuned
#   LRU2Q + tail-age
#   TINYLFU + disabled
#   TINYLFU + eviction-rate
#   TINYLFU + free-mem
#   TINYLFU + hits
#   TINYLFU + lama
#   TINYLFU + marginal-hits
#   TINYLFU + marginal-hits-tuned
#   TINYLFU + tail-age
#
# Step 3: Checking completeness of each trace
#   twitter_cluster10: Complete (has all 24 combinations)
#   twitter_cluster11: Complete (has all 24 combinations)
#   twitter_cluster12: Missing 1 combinations
# ...

# %%
df.columns
# Out:
# Index(['rebalanced_slabs', 'n_rebalanced_slabs', 'miss_ratio', 'throughput',
#        'n_alloc_failures', 'trace_name', 'number_of_requests', 'wsr',
#        'slab_size', 'slab_cnt', 'rebalance_strategy', 'allocator', 'tag',
#        'monitor_interval', 'uuid', 'download_path',
#        'compulsory_miss_ratio_req', 'max_req_size', 'min_obj_size', 'wss',
#        'purpose', 'max_obj_size', 'number_of_req_GiB', 'cpu_requirement',
#        'memory_requirement', 'file_name', 'frequency_mean', 'min_req_size',
#        'number_of_obj_GiB', 'number_of_objects', 'qps', 'num_slab_classes',
#        'compulsory_miss_ratio_byte', 'trace_file', 'category', 'time_span',
#        'thresholdMD', 'minAllocSize', 'mhMinDiffRatio', 'thresholdAD',
#        'lruRefreshSec', 'mhMinDiff', 'countColdTailHitsOnly', 'maxAllocSize',
#        'mhMovingAverageParam', 'rebalanceDiffRatio', 'emrLow', 'cacheSizeMB',
#        'rebalanceStrategy', 'minRequestsObserved', 'lru2qHotPct',
# ...

# %%
# Filter for category == 'twitter-kv' and wsr == 0.01
print("Step 1: Initial filtering")
filtered_df = df[(df['category'] == 'twitter-kv') & (df['wsr'] == 0.01)]
print(f"Data after filtering for category='twitter-kv' and wsr=0.01: {len(filtered_df)} rows")

# Find all existing allocator-rebalance strategy combinations
print("\nStep 2: Finding existing combinations")
existing_combinations = set(filtered_df[['allocator', 'rebalance_strategy']].drop_duplicates().apply(tuple, axis=1))
print(f"Total existing allocator-rebalance strategy combinations: {len(existing_combinations)}")
print("Existing combinations:")
for combo in sorted(existing_combinations):
    print(f"  {combo[0]} + {combo[1]}")

# For each trace, check which combinations it has
print("\nStep 3: Checking completeness of each trace")
trace_combinations = {}
incomplete_traces = []

for trace_name in filtered_df['trace_name'].unique():
    trace_data = filtered_df[filtered_df['trace_name'] == trace_name]
    trace_combos = set(trace_data[['allocator', 'rebalance_strategy']].drop_duplicates().apply(tuple, axis=1))
    trace_combinations[trace_name] = trace_combos
    
    missing_combos = existing_combinations - trace_combos
    if missing_combos:
        incomplete_traces.append(trace_name)
        print(f"  {trace_name}: Missing {len(missing_combos)} combinations")
        for missing in sorted(missing_combos):
            print(f"    - {missing[0]} + {missing[1]}")
    else:
        print(f"  {trace_name}: Complete (has all {len(existing_combinations)} combinations)")

# Keep only traces that have all combinations
complete_traces = [trace for trace in trace_combinations.keys() 
                  if trace_combinations[trace] == existing_combinations]

print(f"\nStep 4: Filtering to complete traces only")
print(f"Complete traces: {len(complete_traces)} out of {len(trace_combinations)} total traces")
print("Complete traces:", complete_traces)

# Filter to only complete traces
final_df = filtered_df[filtered_df['trace_name'].isin(complete_traces)]
print(f"Final dataset: {len(final_df)} rows")

# Group by allocator and rebalance_strategy, compute statistics
print("\nStep 5: Computing statistics by allocator and rebalance_strategy")
if len(final_df) > 0:
    # Check which metrics are available
    metrics_to_analyze = []
    potential_metrics = [
        'miss_ratio_reduction_from_disabled',
        'miss_ratio_reduction_from_lru_disabled'
    ]
    
    for metric in potential_metrics:
        if metric in final_df.columns:
            metrics_to_analyze.append(metric)
        else:
            print(f"Warning: Column '{metric}' not found in data")
    
    print(f"Analyzing metrics: {metrics_to_analyze}")
    
    for metric in metrics_to_analyze:
        print(f"\n{metric}:")
        print("=" * 60)
        stats = final_df.groupby(['allocator', 'rebalance_strategy'])[metric].agg([
            'count',  # number of rows
            'min',    # minimum
            'mean',   # mean
            'max'     # maximum
        ]).round(6)
        display(stats)
else:
    print("No complete traces found - cannot compute statistics")
# Out:
# Step 1: Initial filtering
# Data after filtering for category='twitter-kv' and wsr=0.01: 839 rows
#
# Step 2: Finding existing combinations
# Total existing allocator-rebalance strategy combinations: 24
# Existing combinations:
#   LRU + disabled
#   LRU + eviction-rate
#   LRU + free-mem
#   LRU + hits
#   LRU + lama
#   LRU + marginal-hits
#   LRU + marginal-hits-tuned
#   LRU + tail-age
#   LRU2Q + disabled
#   LRU2Q + eviction-rate
#   LRU2Q + free-mem
#   LRU2Q + hits
#   LRU2Q + lama
#   LRU2Q + marginal-hits
#   LRU2Q + marginal-hits-tuned
#   LRU2Q + tail-age
#   TINYLFU + disabled
#   TINYLFU + eviction-rate
#   TINYLFU + free-mem
#   TINYLFU + hits
#   TINYLFU + lama
#   TINYLFU + marginal-hits
#   TINYLFU + marginal-hits-tuned
#   TINYLFU + tail-age
#
# Step 3: Checking completeness of each trace
#   twitter_cluster10: Complete (has all 24 combinations)
#   twitter_cluster11: Complete (has all 24 combinations)
#   twitter_cluster12: Missing 1 combinations
# ...

# %%
df[(df['category'] == 'twitter-kv') & (df['wsr'] == 0.01) & (df['rebalance_strategy'] == 'hits')].sort_values(by='miss_ratio_percent_reduction_from_disabled')[['trace_name', 'allocator', 'wsr', 'miss_ratio_reduction_from_disabled', 'miss_ratio_percent_reduction_from_disabled']].head(10)
# Out:
#              trace_name allocator   wsr  miss_ratio_reduction_from_disabled  \
# 2134  twitter_cluster49       LRU  0.01                           -0.111038
# 2142  twitter_cluster49     LRU2Q  0.01                           -0.111944
# 2152  twitter_cluster49   TINYLFU  0.01                           -0.099805
# 1221  twitter_cluster28   TINYLFU  0.01                           -0.004965
# 1211  twitter_cluster28     LRU2Q  0.01                           -0.002582
# 1203  twitter_cluster28       LRU  0.01                           -0.002471
# 2390  twitter_cluster54       LRU  0.01                           -0.012390
# 2398  twitter_cluster54     LRU2Q  0.01                           -0.010380
# 908   twitter_cluster20     LRU2Q  0.01                           -0.000824
# 2408  twitter_cluster54   TINYLFU  0.01                           -0.004888
#
#       miss_ratio_percent_reduction_from_disabled
# 2134                                   -0.287021
# ...

# %%
df[(df['rebalance_strategy'] == 'marginal-hits-tuned')].sort_values(by='miss_ratio_percent_reduction_from_disabled', ascending=False)\
    [['trace_name', 'allocator', 'wsr', 'miss_ratio_reduction_from_disabled', 'miss_ratio_percent_reduction_from_disabled']].head(30)
# Out:
#              trace_name allocator   wsr  miss_ratio_reduction_from_disabled  \
# 2072  twitter_cluster47     LRU2Q  0.10                            0.186407
# 2064  twitter_cluster47       LRU  0.10                            0.198779
# 2074  twitter_cluster47   TINYLFU  0.10                            0.186062
# 1435  twitter_cluster33     LRU2Q  0.10                            0.063716
# 1335  twitter_cluster30   TINYLFU  0.10                            0.078671
# 1333  twitter_cluster30     LRU2Q  0.10                            0.075840
# 1325  twitter_cluster30       LRU  0.10                            0.081135
# 2280  twitter_cluster51     LRU2Q  0.10                            0.045939
# 1427  twitter_cluster33       LRU  0.10                            0.066372
# 2282  twitter_cluster51   TINYLFU  0.10                            0.046164
# 2272  twitter_cluster51       LRU  0.10                            0.047288
# ...

# %%
# Group by category and WSR to compare marginal-hits-tuned vs lama
print("Step 1: Filter data for marginal-hits-tuned and lama strategies")
comparison_df = df[df['rebalance_strategy'].isin(['marginal-hits-tuned', 'lama'])].copy()
print(f"Filtered data: {len(comparison_df)} rows")
print(f"Available strategies: {sorted(comparison_df['rebalance_strategy'].unique())}")
print(f"Available categories: {sorted(comparison_df['category'].unique())}")
print(f"Available WSR values: {sorted(comparison_df['wsr'].unique())}")

# Check if we have both strategies
if len(comparison_df['rebalance_strategy'].unique()) < 2:
    print("Warning: Need both 'marginal-hits-tuned' and 'lama' strategies for comparison")
    print(f"Available strategies: {list(comparison_df['rebalance_strategy'].unique())}")
else:
    # Step 2: Pivot data to get miss ratios side by side
    print("\nStep 2: Reshaping data for comparison")
    pivot_data = comparison_df.pivot_table(
        index=['category', 'wsr', 'trace_name', 'allocator'],
        columns='rebalance_strategy',
        values='miss_ratio',
        aggfunc='first'
    )
    
    print(f"Pivot table shape: {pivot_data.shape}")
    print("Sample of pivot data:")
    display(pivot_data.head().round(6))
    
    # Step 3: Calculate comparisons
    print("\nStep 3: Computing comparisons")
    if 'marginal-hits-tuned' in pivot_data.columns and 'lama' in pivot_data.columns:
        # Add comparison column - True if marginal-hits-tuned has lower miss ratio than lama
        pivot_data['marginal_hits_tuned_better'] = pivot_data['marginal-hits-tuned'] < pivot_data['lama']
        
        # Remove rows with missing data
        clean_data = pivot_data.dropna()
        print(f"Clean data (no missing values): {len(clean_data)} rows")
        
        if len(clean_data) > 0:
            # Step 4: Group by category and wsr, compute percentage
            print("\nStep 4: Computing percentage by category and WSR")
            results = []
            
            for (category, wsr), group in clean_data.groupby(['category', 'wsr']):
                total_comparisons = len(group)
                marginal_hits_tuned_wins = group['marginal_hits_tuned_better'].sum()
                percentage_better = (marginal_hits_tuned_wins / total_comparisons) * 100
                
                avg_marginal_hits_tuned = group['marginal-hits-tuned'].mean()
                avg_lama = group['lama'].mean()
                
                results.append({
                    'category': category,
                    'wsr': wsr,
                    'total_comparisons': total_comparisons,
                    'marginal_hits_tuned_wins': marginal_hits_tuned_wins,
                    'percentage_marginal_hits_tuned_better': percentage_better,
                    'avg_miss_ratio_marginal_hits_tuned': avg_marginal_hits_tuned,
                    'avg_miss_ratio_lama': avg_lama,
                    'avg_miss_ratio_difference': avg_marginal_hits_tuned - avg_lama
                })
            
            # Convert to DataFrame for better display
            results_df = pd.DataFrame(results)
            results_df = results_df.sort_values(['category', 'wsr'])
            
            print("Results by category and WSR:")
            print("=" * 80)
            display(results_df.round(6))
            
            # Step 5: Overall summary
            print("\nStep 5: Overall Summary")
            print("=" * 50)
            overall_total = clean_data.shape[0]
            overall_wins = clean_data['marginal_hits_tuned_better'].sum()
            overall_percentage = (overall_wins / overall_total) * 100
            
            print(f"Overall across all categories and WSRs:")
            print(f"  Total comparisons: {overall_total}")
            print(f"  Marginal-hits-tuned wins: {overall_wins}")
            print(f"  Percentage where marginal-hits-tuned < lama: {overall_percentage:.2f}%")
            
            # Summary by category only
            print(f"\nSummary by category:")
            print("-" * 40)
            category_summary = clean_data.groupby('category').agg({
                'marginal_hits_tuned_better': ['count', 'sum', lambda x: (x.sum() / len(x)) * 100],
                'marginal-hits-tuned': 'mean',
                'lama': 'mean'
            }).round(6)
            
            category_summary.columns = ['total_comparisons', 'wins', 'percentage_better', 
                                      'avg_marginal_hits_tuned', 'avg_lama']
            display(category_summary)
            
            # Summary by WSR only  
            print(f"\nSummary by WSR:")
            print("-" * 40)
            wsr_summary = clean_data.groupby('wsr').agg({
                'marginal_hits_tuned_better': ['count', 'sum', lambda x: (x.sum() / len(x)) * 100],
                'marginal-hits-tuned': 'mean', 
                'lama': 'mean'
            }).round(6)
            
            wsr_summary.columns = ['total_comparisons', 'wins', 'percentage_better',
                                 'avg_marginal_hits_tuned', 'avg_lama']
            display(wsr_summary)
            
        else:
            print("No complete data available for comparison")
    else:
        missing_strategies = []
        if 'marginal-hits-tuned' not in pivot_data.columns:
            missing_strategies.append('marginal-hits-tuned')
        if 'lama' not in pivot_data.columns:
            missing_strategies.append('lama')
        print(f"Cannot perform comparison - missing strategies: {missing_strategies}")
        print(f"Available strategies: {list(pivot_data.columns)}")
# Out:
# Step 1: Filter data for marginal-hits-tuned and lama strategies
# Filtered data: 649 rows
# Available strategies: ['lama', 'marginal-hits-tuned']
# Available categories: ['meta-cdn', 'meta-kv', 'twitter-kv', 'wiki-cdn']
# Available WSR values: [np.float64(0.005), np.float64(0.01), np.float64(0.02), np.float64(0.05), np.float64(0.1), np.float64(0.2), np.float64(0.4)]
#
# Step 2: Reshaping data for comparison
# Pivot table shape: (326, 2)
# Sample of pivot data:
# rebalance_strategy                      lama  marginal-hits-tuned
# category wsr  trace_name allocator
# meta-cdn 0.01 meta_reag  LRU        0.383526             0.386545
#                          LRU2Q      0.376509             0.378671
#                          TINYLFU    0.385002             0.388176
#               meta_rnha  LRU        0.642264             0.648929
#                          LRU2Q      0.627733             0.633942
# Step 3: Computing comparisons
# Clean data (no missing values): 323 rows
#
# ...

# %%
df.columns
# Out:
# Index(['rebalanced_slabs', 'n_rebalanced_slabs', 'miss_ratio', 'throughput',
#        'n_alloc_failures', 'trace_name', 'number_of_requests', 'wsr',
#        'slab_size', 'slab_cnt', 'rebalance_strategy', 'allocator', 'tag',
#        'monitor_interval', 'uuid', 'download_path',
#        'compulsory_miss_ratio_req', 'max_req_size', 'min_obj_size', 'wss',
#        'purpose', 'max_obj_size', 'number_of_req_GiB', 'cpu_requirement',
#        'memory_requirement', 'file_name', 'frequency_mean', 'min_req_size',
#        'number_of_obj_GiB', 'number_of_objects', 'qps', 'num_slab_classes',
#        'compulsory_miss_ratio_byte', 'trace_file', 'category', 'time_span',
#        'thresholdMD', 'minAllocSize', 'mhMinDiffRatio', 'thresholdAD',
#        'lruRefreshSec', 'mhMinDiff', 'countColdTailHitsOnly', 'maxAllocSize',
#        'mhMovingAverageParam', 'rebalanceDiffRatio', 'emrLow', 'cacheSizeMB',
#        'rebalanceStrategy', 'minRequestsObserved', 'lru2qHotPct',
# ...
